# %% [markdown]
# ## Parsing HTML

# %% [markdown]
# #### <span style="background-color: #FFFF00">**Beautiful Soup**</span> is a Pythin library that helps parse HTML code for you, so you don't have to write a lot of complex regular expressions yourself.
#
# BeautifulSoup is often used in conjunction with the *requests* library, since it's primary purpose is to parse HTML pages that are downloaded from websites.

# %%
import requests

# %%
response = requests.get('https://www.spiced-academy.com/en/program/data-science')

# %%
response.status_code
# Out:
# 200

# %%
#response.text #  gives hmtl text

# %% [markdown]
# #### When we get the content, or "text" of an HTTP request in python, we get the raw HTML code of that webpage.
# - more specifically, we get the response as a python string

# %% [markdown]
# #### Let's make our lives a bit easier and convert this python string to a more meaningful object that understands the structure of HTML.

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# #### Convert the raw HTML string to a BeautifulSoup object, so that you can parse the data.

# %%
soup = BeautifulSoup(response.text)
soup
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">
# <head>
# <title>Data Science Bootcamp in Germany | Spiced Academy</title>
# <meta content="Level up your career with our 12 week Data Science bootcamp in Germany." name="description"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="https://fonts.googleapis.com/css?family=Poppins:300,400,600&amp;display=swap" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=IBM+Plex+Mono:400,500&amp;display=swap" rel="stylesheet"/>
# <link href="/css/main.css" rel="stylesheet"/>
# <link href="/apple-touch-icon.png?v=3" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/favicon-32x32.png?v=3" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/favicon-16x16.png?v=3" rel="icon" sizes="16x16" type="image/png"/>
# <link color="#5bbad5" href="/safari-pinned-tab.svg" rel="mask-icon"/>
# <meta content="#da532c" name="msapplication-TileColor"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="DICJgJwgfNeeiq66MAwDzpaeqBBgDqZsBNFBMwVtoaY" name="google-site-verification"/>
# <meta content="#2E016D" name="theme-color"/>
# <meta content="noodp" name="robots"/>
# <link href="https://www.spiced-academy.com/en/program/data-science" rel="canonical"/>
# <link href="https://www.spiced-academy.com/en/program/data-science" hreflang="en" rel="alternate"/>
# <link href="https://www.spiced-academy.com/de/program/data-science" hreflang="de" rel="alternate"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="article" property="og:type"/>
# <meta content="Spiced Academy | Your new career starts here" property="og:title"/>
# <meta content="Kickstart your new career with our intensive, on-site tech programs in Web Development and Data Science." property="og:description"/>
# <meta content="https://www.spiced-academy.com/program/data-science" property="og:url"/>
# <meta content="Spiced Academy" property="og:site_name"/>
# <meta content="https://www.facebook.com/spicedacademy" property="article:publisher"/>
# <meta content="1214485688610932" property="fb:app_id"/>
# <meta content="https://www.spiced-academy.com/img/people/spiced_share.jpg" property="og:image"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="Level up your career with our 12 week Data Science bootcamp in Germany." name="twitter:description"/>
# <meta content="Data Science Bootcamp in Germany | Spiced Academy – A Coding Academy in Berlin" name="twitter:title"/>
# <meta content="@SPICEDacademy" name="twitter:site"/>
# <meta content="https://www.spiced-academy.com/img/people/spiced_share.jpg" name="twitter:image"/>
# <meta content="@SPICEDacademy" name="twitter:creator"/>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-78282401-1"></script>
# <script>
#       window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#       gtag('config', 'UA-78282401-1');
#       gtag('config', 'AW-882057422');
#     </script>
# <script async="" defer="" src="https://www.google.com/recaptcha/api.js"></script>
# <!-- Facebook Pixel Code -->
# <script>
#     !function(f,b,e,v,n,t,s)
#     {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#     n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#     if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#     n.queue=[];t=b.createElement(e);t.async=!0;
#     t.src=v;s=b.getElementsByTagName(e)[0];
#     s.parentNode.insertBefore(t,s)}(window,document,'script',
#     'https://connect.facebook.net/en_US/fbevents.js');
#      fbq('init', '1628135084116192');
#     fbq('track', 'PageView');
#     </script>
# <noscript>
# <img height="1" src="https://www.facebook.com/tr?id=1628135084116192&amp;ev=PageView
#     &amp;noscript=1" width="1"/>
# </noscript>
# <!-- End Facebook Pixel Code -->
# <!-- DO NOT MODIFY -->
# <script>
#     var i=new Image();i.src="https://alb.reddit.com/snoo.gif?q=CAAHAAABAAoACQAAAAAETYmbAA==&s=eUBwdmUHxwTWcJzXvTt1feUOEDHpTyhp333E0DdefAM=https://alb.reddit.com/snoo.gif?q=CAAHAAABAAoACQAAAAAETYmbAA==&s=eUBwdmUHxwTWcJzXvTt1feUOEDHpTyhp333E0DdefAM=";
#     </script>
# <noscript>
# <img height="1" src="https://alb.reddit.com/snoo.gif?q=CAAHAAABAAoACQAAAAAETYmbAA==&amp;s=eUBwdmUHxwTWcJzXvTt1feUOEDHpTyhp333E0DdefAM=
#     https://alb.reddit.com/snoo.gif?q=CAAHAAABAAoACQAAAAAETYmbAA==&amp;s=eUBwdmUHxwTWcJzXvTt1feUOEDHpTyhp333E0DdefAM=
#     " style="display:none" width="1"/>
# </noscript>
# <!-- End Reddit Conversion Pixel --></head>
# <body>
# <header>
# <div class="header header-left">
# <a href="/">
# <img alt="Spiced logo" class="header-logo" src="/img/Spiced_Logo_Dark.svg"/>
# </a>
# <div class="header-links">
# <a href="/program">
# <p class="js-header-links-left">PROGRAMS</p>
# </a>
# <a href="/about">
# <p class="js-header-links-left">ABOUT</p>
# </a>
# <a class="apply-now" href="/apply">
# <p class="js-header-links-left">APPLY NOW</p>
# </a>
# </div>
# </div>
# <div class="header header-right">
# <div class="header-links fade-header">
# <a href="/program">
# <p class="js-header-links-right">PROGRAMS</p>
# </a>
# <a href="/about">
# <p class="js-header-links-right">ABOUT</p>
# </a>
# <a class="apply-now" href="/apply">
# <p class="js-header-links-right">APPLY NOW</p>
# </a>
# </div>
# <p class="js-language-toggle"><a href="/lng/de" style="font-weight:100;">DE</a> | <a href="/lng/en" style="font-weight:900;">EN</a></p>
# <div id="nav-icon">
# <span></span>
# <span></span>
# </div>
# </div>
# <div class="header-sidebar-container">
# <p class="js-language-toggle"><a href="/lng/de" style="font-weight:100;">DE</a> | <a href="/lng/en" style="font-weight:900;">EN</a></p>
# <hr/>
# <div class="main-hamburger-links">
# <a href="/program">
# <p>Programs</p>
# </a>
# <a href="/about">
# <p>About</p>
# </a>
# </div>
# <hr/>
# <div class="sub-hamburger-links">
# <a href="/graduates">
# <p>Graduates</p>
# </a>
# <a href="/outcomes">
# <p>Outcomes</p>
# </a>
# <a href="/faq">
# <p>FAQ</p>
# </a>
# <a href="https://blog.spiced-academy.com/" target="”_blank”">
# <p>Blog</p>
# </a>
# </div>
# <a class="apply-now" href="/apply">
# <p>APPLY NOW</p>
# </a>
# </div>
# </header>
# <div class="scroll-container">
# <section class="js-header-left-dark mob-col-reverse">
# <div class="panel">
# <div class="program-intro-panel text-container--simple">
# <h1 class="main-heading">Data <br/> Science</h1>
# <h3 class="sub-heading">Level up your career with our 12 week Data Science bootcamp in Germany.</h3>
# <h3>Campuses in <a href="/program/data-science/berlin">Berlin</a>, <a href="/program/data-science/hamburg">Hamburg</a>, <a href="/program/data-science/cologne">Cologne</a> and <a href="/program/data-science/stuttgart">Stuttgart</a></h3>
# <div class="program-intro-top-btn">
# <a class="read-more-btn" href="#prep-section">
# <button class="btn btn--secondary">Read More</button>
# </a>
# <a href="/apply?course=data-science">
# <button class="btn btn--primary">Take the Leap</button>
# </a>
# </div>
# </div> </div>
# <div class="panel bg-color-primary-light duel-background duel-background--reverse">
# <div class="circle-image-container">
# <div class="circle-half circle-half--right" style="background-image: url(/img/people/spiced-academy-data-science-bootcamp.jpg)"></div>
# <div class="top-left-circle circle-quarter bg-color-pink"></div>
# <div class="bottom-left-circle circle-quarter bg-color-white"></div>
# </div> </div>
# </section>
# <section class="js-header-left-light js-header-right-dark preparation-phases" id="prep-section">
# <div class="panel mob-top-panel mob-three-quarter-panel">
# <div class="triangle-top-left-action-rev"></div>
# <h1 class="main-heading career-heading career-start-container">Your new career starts here</h1>
# </div>
# <div class="panel bg-color-white mob-quarter-panel student-0 fade-in">
# <div class="preparation-container">
# <div class="content-container">
# <p class="mob-hidden">0/4</p>
# <h2 class="preparation-title">Preparation Phase</h2>
# <h3 class="preparation-short-description">Get started with the core skills that you need</h3>
# <p class="preparation-long-description">Using Python basics, Linear Algebra and calculus, you will learn to write your very first programs. You’ll begin working with programming fundamentals such as data types, loops and conditionals. Once you’ve finished the prep course, you’re required to solve a small data analysis challenge to make sure you’re up to speed and ready for the on-site portion of our coding bootcamp.</p>
# </div>
# <div class="flex">
# <p class="mob-only">0/4</p>
# <div class="js-prep-next next-container">
# <a class="link js-next-prep-phase" href="#">Next</a>
# <div class="shape-box-small flex" id="">
# <div class="shape-box-small--chevron"></div>
# <div class="shape-box-small--chevron"></div>
# </div> </div>
# </div>
# </div>
# </div> <div class="panel mob-top-panel mob-three-quarter-panel">
# <div class="triangle-top-left-action-rev"></div>
# <h1 class="main-heading career-heading career-start-container">Your new career starts here</h1>
# </div>
# <div class="panel bg-color-white mob-quarter-panel student-1 fade-out">
# <div class="preparation-container">
# <div class="content-container">
# <p class="mob-hidden">1/4</p>
# <h2 class="preparation-title">Phase I</h2>
# <h3 class="preparation-short-description">Machine learning, data analysis and more</h3>
# <p class="preparation-long-description">We’ll kick off the course with data analysis and machine learning with Python on a different project each week. You’ll learn to use the pandas library to rapidly wrangle and visualize datasets, as well as learning to train models with scikit-learn. You’ll get under the hood and start to learn the maths behind the models, and learn to optimize model performance and discuss business cases. In this phase you’ll also get started with Deep Learning and get your computer to understand images and text in order to build a recommender system.</p>
# </div>
# <div class="flex">
# <p class="mob-only">1/4</p>
# <div class="js-prep-next next-container">
# <a class="link js-next-prep-phase" href="#">Next</a>
# <div class="shape-box-small flex" id="">
# <div class="shape-box-small--chevron"></div>
# <div class="shape-box-small--chevron"></div>
# </div> </div>
# </div>
# </div>
# </div> <div class="panel mob-top-panel mob-three-quarter-panel">
# <div class="triangle-top-left-action-rev"></div>
# <h1 class="main-heading career-heading career-start-container">Your new career starts here</h1>
# </div>
# <div class="panel bg-color-white mob-quarter-panel student-2 fade-out">
# <div class="preparation-container">
# <div class="content-container">
# <p class="mob-hidden">2/4</p>
# <h2 class="preparation-title">Phase II</h2>
# <h3 class="preparation-short-description">Time for the back-end.</h3>
# <p class="preparation-long-description">For bigger datasets, databases are must-have. You’ll store data in a SQL database, install your programs on a remote server and manage entire data pipelines. You’ll learn to manage PostgreSQL databases, examine query performance and do full-text search. You’ll deploy programs to cloud servers, building an interactive dashboard. Coordinate databases, web APIs and ETL jobs using Airflow and Docker. Finally, you’ll use Software Engineering techniques to write bigger software cleanly.</p>
# </div>
# <div class="flex">
# <p class="mob-only">2/4</p>
# <div class="js-prep-next next-container">
# <a class="link js-next-prep-phase" href="#">Next</a>
# <div class="shape-box-small flex" id="">
# <div class="shape-box-small--chevron"></div>
# <div class="shape-box-small--chevron"></div>
# </div> </div>
# </div>
# </div>
# </div> <div class="panel mob-top-panel mob-three-quarter-panel">
# <div class="triangle-top-left-action-rev"></div>
# <h1 class="main-heading career-heading career-start-container">Your new career starts here</h1>
# </div>
# <div class="panel bg-color-white mob-quarter-panel student-3 fade-out">
# <div class="preparation-container">
# <div class="content-container">
# <p class="mob-hidden">3/4</p>
# <h2 class="preparation-title">Phase III</h2>
# <h3 class="preparation-short-description">Deep learning and your final project</h3>
# <p class="preparation-long-description">Time for the world of Deep Learning. You’ll learn how to build image processing systems and language processing systems with Keras. You’ll also get an overview of state-of-the-art technologies such as Adversarial Networks and Reinforcement Learning. In the final two weeks of the course you’ll combine everything you’ve learnt in your self-defined final project.</p>
# </div>
# <div class="flex">
# <p class="mob-only">3/4</p>
# <div class="js-prep-next next-container">
# <a class="link js-next-prep-phase" href="#">Next</a>
# <div class="shape-box-small flex" id="">
# <div class="shape-box-small--chevron"></div>
# <div class="shape-box-small--chevron"></div>
# </div> </div>
# </div>
# </div>
# </div> <div class="panel mob-top-panel mob-three-quarter-panel">
# <div class="triangle-top-left-action-rev"></div>
# <h1 class="main-heading career-heading career-start-container">Your new career starts here</h1>
# </div>
# <div class="panel bg-color-white mob-quarter-panel student-4 fade-out">
# <div class="preparation-container">
# <div class="content-container">
# <p class="mob-hidden">4/4</p>
# <h2 class="preparation-title">Phase IV</h2>
# <h3 class="preparation-short-description">A place to continue to learn and develop.</h3>
# <p class="preparation-long-description">Having completed the Data Science bootcamp, you’re free to come to Spiced to continue to work and hone your portfolio. Spiced will keep its doors open to you for 6 weeks after graduation, allowing you to receive guidance during your job search and put any final touches needed on your portfolio.</p>
# </div>
# <div class="flex">
# <p class="mob-only">4/4</p>
# <div class="js-prep-next next-container">
# <a class="link js-next-prep-phase" href="#">Next</a>
# <div class="shape-box-small flex" id="">
# <div class="shape-box-small--chevron"></div>
# <div class="shape-box-small--chevron"></div>
# </div> </div>
# </div>
# </div>
# </div>
# </section>
# <section class="js-header-left-dark js-header-right-dark mob-relative">
# <div class="curriculum-container mob-top-panel">
# <div class="curriculum-top">
# <h2>Curriculum</h2>
# <h3>Know your language at glance:</h3>
# </div>
# <div class="curriculum-middle">
# <div class="curriculum-mini-section">
# <div class="shape-box-small">
# <div class="shape-box-small--half-box"></div>
# <div class="half-box-border"></div>
# </div> <div class="description">
# <h3>Data Analysis in Python</h3>
# <h3 class="mob-hidden">Become fluent in using Python to collect, analyze, and visualize data, focusing on the powerful libraries Pandas &amp; NumPy.</h3>
# </div>
# </div>
# <div class="curriculum-mini-section">
# <div class="shape-box-small">
# <div class="shape-box-small--square-border"></div>
# </div> <div class="description">
# <h3>Machine Learning</h3>
# <h3 class="mob-hidden">Delve into the world of supervised and unsupervised learning with the scikit-learn and statsmodels frameworks.</h3>
# </div>
# </div>
# <div class="curriculum-mini-section">
# <div class="shape-box-small">
# <div class="shape-box-small--half-box half-box-dark-purple"></div>
# <div class="shape-box-small--half-box"></div>
# </div> <div class="description">
# <h3>PostgreSQL</h3>
# <h3 class="mob-hidden">Organize data in SQL databases like PostgreSQL, fill it with data and run queries.</h3>
# </div>
# </div>
# <div class="curriculum-mini-section">
# <div class="shape-box-small flex">
# <div class="shape-box-small--chevron-large"></div>
# <div class="shape-box-small--chevron-large"></div>
# </div> <div class="description">
# <h3>Data Infrastructure</h3>
# <h3 class="mob-hidden">Deploy code on remote servers using Docker and AWS, and build an online dashboard.</h3>
# </div>
# </div>
# <div class="curriculum-mini-section">
# <div class="shape-box-small">
# <div class="shape-box-small--triangle-top-right-purple"></div>
# </div> <div class="description">
# <h3>Software Engineering</h3>
# <h3 class="mob-hidden">Acquire state-of-the-art engineering tools to write, test, and deploy bigger Python applications.</h3>
# </div>
# </div>
# <div class="curriculum-mini-section">
# <div class="shape-box-small">
# <div class="shape-box-small--circle"></div>
# </div> <div class="description">
# <h3>Git &amp; Bash</h3>
# <h3 class="mob-hidden">Use Git and GitHub throughout the course to collaborate &amp; version control your code.</h3>
# </div>
# </div>
# </div>
# <div class="curriculum-bottom">
# <div>
# <h3 class="find-out-more">Want to find out more?</h3>
# <a class="download-curriculum-link" download="" href="/pdfs/spiced-academy-data-science-curriculum.pdf">
# <button class="btn btn--secondary">Download Curriculum</button>
# </a>
# </div>
# </div>
# </div></section>
# <section class="js-header-left-dark js-header-right-light mob-col-reverse">
# <div class="panel bg-color-white mob-two-thirds-panel">
# <div class="action-box action-box--right">
# <h1 class="main-heading main-heading--off-center-left main-heading--space-bottom">Career <br/> Services</h1>
# <div class="shape-box-small small-shape-spacer-container">
# <div class="shape-box-small--triangle-top-right-pink"></div>
# </div>
# <p class="bold mob-hidden">Practical, real-world approach</p>
# <p class="mob-only career-mob-heading">Real-world technical interviews</p>
# <p class="mob-hidden p-smaller">An extensive focus on passing real-world technical interviews.</p>
# <div class="shape-box-small small-shape-spacer-container">
# <div class="shape-box-small--triangle-top-right-pink"></div>
# </div>
# <p class="bold mob-hidden">Tailored coaching sessions</p>
# <p class="mob-only career-mob-heading">Tailored coaching sessions</p>
# <p class="mob-hidden p-smaller">Unlimited one-to-one coaching sessions, helping you to develop professionally.</p>
# <div class="shape-box-small small-shape-spacer-container">
# <div class="shape-box-small--triangle-top-right-pink"></div>
# </div>
# <p class="bold mob-hidden">More than just technical skills</p>
# <p class="mob-only career-mob-heading">Professional development</p>
# <p class="mob-hidden p-smaller">We're here to support you with the personal changes in your career transition, too.</p>
# <div class="shape-box-small small-shape-spacer-container">
# <div class="shape-box-small--triangle-top-right-pink"></div>
# </div>
# <p class="bold mob-hidden">An insider view</p>
# <p class="mob-only career-mob-heading">An insider view</p>
# <p class="mob-hidden p-smaller">We share the insider view of the the latest recruitment processes in Germany and beyond.</p>
# </div> </div>
# <div class="panel">
# <img alt="career-services" class="single-panel-image student-built-image" src="/img/staff/career-services.jpg"/> </div>
# </section>
# <section class="js-header-left-dark js-header-right-dark graduate-testimonials">
# <div class="panel min-height-panel bg-color-white mob-top-panel mob-center student-0 fade-in">
# <div class="circle-image-container">
# <div class="circle-half circle-half--left" style="background-image: url(/img/testimonials/alumni-kent-spiced.jpg); ">
# </div>
# <div class="top-right-circle circle-quarter bg-color-pink">
# <div class="next-link-container">
# <p class="link js-next-student-testimonials">Next</p>
# <div class="shape-box-small small-shape-spacer-container">
# <div class="shape-box-small--chevron shape-box-small--chevron--white"></div>
# <div class="shape-box-small--chevron shape-box-small--chevron--white"></div>
# </div>
# </div>
# </div>
# <div class="bottom-right-circle circle-quarter bg-color-action"></div>
# </div></div>
# <div class="panel flex-center student-0 fade-in">
# <div class=""></div>
# <div class="text-container text-container--simple text-container--center-short-txt">
# <h1 class="main-heading main-heading--space-bottom main-heading--primary">
#                 What our students say:
#
#
#             </h1>
# <div class="career-start-container--subheading-container">
# <div class="shape-box-small small-shape-spacer-container">
# <div class="shape-box-small--triangle-top-right"></div>
# </div>
# <div>
# <h4 class="sub-heading sub-heading--primary-light">
#                             Kent Troutman<br/>Data Scientist at Deutsche Bundesbank
#                         </h4>
# <p class="text-container-height">The intense method of the boot camp helped me get to the next level skill-wise. I kept up my end and worked hard, as did my classmates, and Kristian made sure that no one was left behind.</p>
# </div>
# </div>
# </div>
# </div> <div class="panel min-height-panel bg-color-white mob-top-panel mob-center student-1 fade-out">
# <div class="circle-image-container">
# <div class="circle-half circle-half--left" style="background-image: url(/img/testimonials/alumni-lilian-spiced.jpg); ">
# </div>
# <div class="top-right-circle circle-quarter bg-color-pink">
# <div class="next-link-container">
# <p class="link js-next-student-testimonials">Next</p>
# <div class="shape-box-small small-shape-spacer-container">
# <div class="shape-box-small--chevron shape-box-small--chevron--white"></div>
# <div class="shape-box-small--chevron shape-box-small--chevron--white"></div>
# </div>
# </div>
# </div>
# <div class="bottom-right-circle circle-quarter bg-color-action"></div>
# </div></div>
# <div class="panel flex-center student-1 fade-out">
# <div class=""></div>
# <div class="text-container text-container--simple text-container--center-short-txt">
# <h1 class="main-heading main-heading--space-bottom main-heading--primary">
#                 What our students say:
#
#
#             </h1>
# <div class="career-start-container--subheading-container">
# <div class="shape-box-small small-shape-spacer-container">
# <div class="shape-box-small--triangle-top-right"></div>
# </div>
# <div>
# <h4 class="sub-heading sub-heading--primary-light">
#                             Lilian van Someren Greve<br/>Junior Data Scientist at TeamViewer
#                         </h4>
# <p class="text-container-height">Having worked in Business Intelligence, Spiced was able to bridge the gaps in my knowledge regarding Python and a deeper understanding of how some key Data Science models work. You can learn an amazing amount in 3 months, if you're willing to.</p>
# </div>
# </div>
# </div>
# </div> <div class="panel min-height-panel bg-color-white mob-top-panel mob-center student-2 fade-out">
# <div class="circle-image-container">
# <div class="circle-half circle-half--left" style="background-image: url(/img/testimonials/alumni-helena-spiced.jpg); ">
# </div>
# <div class="top-right-circle circle-quarter bg-color-pink">
# <div class="next-link-container">
# <p class="link js-next-student-testimonials">Next</p>
# <div class="shape-box-small small-shape-spacer-container">
# <div class="shape-box-small--chevron shape-box-small--chevron--white"></div>
# <div class="shape-box-small--chevron shape-box-small--chevron--white"></div>
# </div>
# </div>
# </div>
# <div class="bottom-right-circle circle-quarter bg-color-action"></div>
# </div></div>
# <div class="panel flex-center student-2 fade-out">
# <div class=""></div>
# <div class="text-container text-container--simple text-container--center-short-txt">
# <h1 class="main-heading main-heading--space-bottom main-heading--primary">
#                 What our students say:
#
#
#             </h1>
# <div class="career-start-container--subheading-container">
# <div class="shape-box-small small-shape-spacer-container">
# <div class="shape-box-small--triangle-top-right"></div>
# </div>
# <div>
# <h4 class="sub-heading sub-heading--primary-light">
#                             Helena Schock<br/>Data Scientist at Hummingbird Diagnostics
#                         </h4>
# <p class="text-container-height">Class is intense, but in a good way. Looking back at the 12 weeks I spent at Spiced with such an amazing group of people, I wouldn’t want to miss any of it.</p>
# </div>
# </div>
# </div>
# </div> <div class="panel min-height-panel bg-color-white mob-top-panel mob-center student-3 fade-out">
# <div class="circle-image-container">
# <div class="circle-half circle-half--left" style="background-image: url(/img/testimonials/alumni-konstantin-spiced.jpg); ">
# </div>
# <div class="top-right-circle circle-quarter bg-color-pink">
# <div class="next-link-container">
# <p class="link js-next-student-testimonials">Next</p>
# <div class="shape-box-small small-shape-spacer-container">
# <div class="shape-box-small--chevron shape-box-small--chevron--white"></div>
# <div class="shape-box-small--chevron shape-box-small--chevron--white"></div>
# </div>
# </div>
# </div>
# <div class="bottom-right-circle circle-quarter bg-color-action"></div>
# </div></div>
# <div class="panel flex-center student-3 fade-out">
# <div class=""></div>
# <div class="text-container text-container--simple text-container--center-short-txt">
# <h1 class="main-heading main-heading--space-bottom main-heading--primary">
#                 What our students say:
#
#
#             </h1>
# <div class="career-start-container--subheading-container">
# <div class="shape-box-small small-shape-spacer-container">
# <div class="shape-box-small--triangle-top-right"></div>
# </div>
# <div>
# <h4 class="sub-heading sub-heading--primary-light">
#                             Konstanin Mack<br/>Data Scientist at Football Radar
#                         </h4>
# <p class="text-container-height">Kristian, the head teacher, is just amazing. He knows everything about Data Science and - maybe even more importantly - you can see that he really enjoys teaching.</p>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="js-header-left-dark js-header-right-dark mob-col-reverse graduate-projects">
# <div class="panel bg-color-white student-0 fade-in">
# <div class="js-next-students-built students-built-container">
# <h2 class="mob-hidden"> What our students <br/> have built</h2>
# <h2 class="mob-only students-built-title-mob">What our students <br/> have built</h2>
# <a href="https://github.com/GMattheisen/predicting_Alzheimers_from_MRI" rel="nofollow noreferrer" target="_blank">
# <p class="built-sub-heading sub-heading">Predicting Alzheimer's from MRI</p>
# </a>
# <h3 class="student-name">by Glynnis M.</h3>
# <div class="project-summary">Distinguishes the brains of cognitively normal patients from those diagnosed with Alzheimer's.
#
#             </div>
# <div class="next-container">
# <a class="link js-next-students-built" href="#" rel="nofollow noreferrer">Next</a>
# <div class="shape-box-small flex" id="">
# <div class="shape-box-small--chevron"></div>
# <div class="shape-box-small--chevron"></div>
# </div> </div>
# </div>
# </div>
# <div class="panel mob-top-panel student-0 fade-in">
# <a href="https://github.com/GMattheisen/predicting_Alzheimers_from_MRI" rel="nofollow noreferrer" target="_blank">
# <div class="action-box action-box--full">
# <img alt="glynnis mattheisen" class="single-panel-image student-built-image" src="/img/projects/glynnis-mattheisen.jpg"/> </div>
# </a>
# </div> <div class="panel bg-color-white student-1 fade-out">
# <div class="js-next-students-built students-built-container">
# <h2 class="mob-hidden"> What our students <br/> have built</h2>
# <h2 class="mob-only students-built-title-mob">What our students <br/> have built</h2>
# <a href="https://github.com/steffmul/nextbike" rel="nofollow noreferrer" target="_blank">
# <p class="built-sub-heading sub-heading">Analysis of Next Bike in Berlin</p>
# </a>
# <h3 class="student-name">by Steffen M.</h3>
# <div class="project-summary">Analyzed appx. 10.000 trips in Berlin to forecast daily &amp; hourly demand.
#
#             </div>
# <div class="next-container">
# <a class="link js-next-students-built" href="#" rel="nofollow noreferrer">Next</a>
# <div class="shape-box-small flex" id="">
# <div class="shape-box-small--chevron"></div>
# <div class="shape-box-small--chevron"></div>
# </div> </div>
# </div>
# </div>
# <div class="panel mob-top-panel student-1 fade-out">
# <a href="https://github.com/steffmul/nextbike" rel="nofollow noreferrer" target="_blank">
# <div class="action-box action-box--full">
# <img alt="steffen mueller" class="single-panel-image student-built-image" src="/img/projects/steffen-mueller.jpg"/> </div>
# </a>
# </div> <div class="panel bg-color-white student-2 fade-out">
# <div class="js-next-students-built students-built-container">
# <h2 class="mob-hidden"> What our students <br/> have built</h2>
# <h2 class="mob-only students-built-title-mob">What our students <br/> have built</h2>
# <a href="https://github.com/LeanderNicolai/ALPR-Logistics" rel="nofollow noreferrer" target="_blank">
# <p class="built-sub-heading sub-heading">Automatic License Plate Recognition</p>
# </a>
# <h3 class="student-name">by Nicolai van der L.</h3>
# <div class="project-summary">Focused on the recognition and OCR of license plates for the automation &amp; optimization of logistics management in warehouses.
#
#             </div>
# <div class="next-container">
# <a class="link js-next-students-built" href="#" rel="nofollow noreferrer">Next</a>
# <div class="shape-box-small flex" id="">
# <div class="shape-box-small--chevron"></div>
# <div class="shape-box-small--chevron"></div>
# </div> </div>
# </div>
# </div>
# <div class="panel mob-top-panel student-2 fade-out">
# <a href="https://github.com/LeanderNicolai/ALPR-Logistics" rel="nofollow noreferrer" target="_blank">
# <div class="action-box action-box--full">
# <img alt="nicolai van der laan" class="single-panel-image student-built-image" src="/img/projects/nicolai-vanderlaan.jpg"/> </div>
# </a>
# </div> <div class="panel bg-color-white student-3 fade-out">
# <div class="js-next-students-built students-built-container">
# <h2 class="mob-hidden"> What our students <br/> have built</h2>
# <h2 class="mob-only students-built-title-mob">What our students <br/> have built</h2>
# <a href="https://github.com/PaulineBru/Aspect-Based-Sentiment-Mining" rel="nofollow noreferrer" target="_blank">
# <p class="built-sub-heading sub-heading">Aspect-Based Sentiment Mining</p>
# </a>
# <h3 class="student-name">by Pauline B.</h3>
# <div class="project-summary">A drug therapy recommender system that analyzes drug reviews from different data sets.
#
#                 <p class="disclaimer">*This project is a replication of a research paper.</p>
# </div>
# <div class="next-container">
# <a class="link js-next-students-built" href="#" rel="nofollow noreferrer">Next</a>
# <div class="shape-box-small flex" id="">
# <div class="shape-box-small--chevron"></div>
# <div class="shape-box-small--chevron"></div>
# </div> </div>
# </div>
# </div>
# <div class="panel mob-top-panel student-3 fade-out">
# <a href="https://github.com/PaulineBru/Aspect-Based-Sentiment-Mining" rel="nofollow noreferrer" target="_blank">
# <div class="action-box action-box--full">
# <img alt="pauline brucki" class="single-panel-image student-built-image" src="/img/projects/pauline-brucki1.jpg"/> </div>
# </a>
# </div>
# </section>
# <section class="js-header-left-light js-header-right-light">
# <div class="full-width-panel bg-color-primary-light primary-dark-triangle-sm full-width-triangle-top-right--mob-hidden">
# <div class="where-our-grads-work-container">
# <div class="where-our-grads-work">
# <h1 class="main-heading main-heading--secondary">Where our graduates work</h1>
# <div class="company-logo-container">
# <img alt="ebay" src="/img/company-logos/ebay-logo-white.svg"/>
# </div>
# <div class="company-logo-container">
# <img alt="thoughtworks" src="/img/company-logos/thoughtworks-logo-white.svg"/>
# </div>
# <div class="company-logo-container">
# <img alt="soundcloud" src="/img/company-logos/soundcloud-logo-white.svg"/>
# </div>
# <div class="company-logo-container">
# <img alt="accenture" src="/img/company-logos/accenture-logo-white.svg"/>
# </div>
# <div class="company-logo-container">
# <img alt="zalando" src="/img/company-logos/zalando-logo-white.svg"/>
# </div>
# <div class="company-logo-container">
# <img alt="bcg" src="/img/company-logos/bcg-logo-white.svg"/>
# </div>
# <div class="company-logo-container">
# <img alt="audible" src="/img/company-logos/audible-logo-white.svg"/>
# </div>
# <div class="company-logo-container">
# <img alt="wework" src="/img/company-logos/wework-logo-white.svg"/>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="js-header-left-light js-header-right-dark mob-col-reverse min-height-section">
# <div class="panel min-height-panel">
# <div class="half-panel min-height-mob-50 bg-color-primary-light flex-center landscape-inherit">
# <div class="text-container-narrow">
# <h2 class="main-heading lighter">Take the next step in your career</h2>
# </div>
# </div>
# <div class="half-panel panel-center bg-color-primary-dark min-height-mob-50">
# <div class="text-container-narrow">
# <h3 class="sub-heading sub-heading--white sub-heading--program-dates">
#                     Our Data Science courses in Germany are available for funding with the Agentur für Arbeit.
#                 </h3>
# <div class="program-links-container">
# <div class="shape-box-small small-shape-spacer-container">
# <div class="shape-box-small--chevron"></div>
# <div class="shape-box-small--chevron"></div>
# </div>
# <a class="link" href="/learn-to-code-free">Find out more here.</a>
# </div>
# </div>
# </div>
# </div>
# <div class="panel min-height-panel mob-three-quarter-panel">
# <div class="mob-only">
# <div class="bg-color-primary-dark flex-center landscape-inherit">
# <div class="text-container-narrow mob-program-dates">
# <h2 class="main-heading lighter">Dates</h2>
# </div>
# </div>
# </div>
# <div class="text-container-narrow">
# <div class="city-dates-container">
# <h2 class="secondary-heading">Berlin</h2>
# <h3 class="sub-heading">Next cohort starts: September 28, 2020</h3>
# <a href="/apply?city=berlin&amp;course=data-science">
# <button class="btn btn--secondary">Start Application</button>
# </a>
# </div>
# <div class="city-dates-container">
# <h2 class="secondary-heading">Hamburg</h2>
# <h3 class="sub-heading">Next cohort starts: October 12, 2020</h3>
# <a href="/apply?city=hamburg&amp;course=data-science">
# <button class="btn btn--secondary">Start Application</button>
# </a>
# </div>
# <div class="city-dates-container">
# <h2 class="secondary-heading">Cologne</h2>
# <h3 class="sub-heading">Next cohort starts: September 14, 2020</h3>
# <a href="/apply?city=cologne&amp;course=data-science">
# <button class="btn btn--secondary">Start Application</button>
# </a>
# </div>
# <div class="city-dates-container">
# <h2 class="secondary-heading">Stuttgart</h2>
# <h3 class="sub-heading">Next cohort starts: September 14, 2020</h3>
# <a href="/apply?city=stuttgart&amp;course=data-science">
# <button class="btn btn--secondary">Start Application</button>
# </a>
# </div>
# </div>
# </div>
# </section>
# <script src="/js/graduate-testimonials-circles.js"></script>
# <section class="mob-bg-color-primary-dark" id="contact-us">
# <footer>
# <div class="footer-top-container mob-smaller-panel mob-top-panel">
# <div class="panel-footer panel-footer--flex">
# <div class="footer-top-panel">
# <div class="mob-hidden">
# <h2>Questions?</h2>
# <p class="sub-heading sub-heading--grey">You can head to our <a href="/faq">FAQ</a> page or...</p>
# </div>
# <a href="https://calendly.com/spicedacademy/15min?month=2020-02" rel="nofollow noopener" target="_blank">
# <button class="btn btn--primary">Schedule a Chat</button>
# </a>
# </div>
# </div>
# <div class="panel-footer panel-footer--flex bg-color-primary-light">
# <div class="footer-top-panel footer-top-panel--white">
# <div class="mob-hidden">
# <h2 class="lighter">Ready?</h2>
# <p class="sub-heading">Take the leap and begin your application online.</p>
# </div>
# <a href="/apply">
# <button class="btn btn--secondary">Start Application</button>
# </a>
# </div>
# </div>
# </div>
# <div class="footer-bottom-container bg-color-primary-dark mob-bigger-panel">
# <div class="panel-footer panel-footer--flex">
# <div class="footer-bottom-left">
# <p class="sub-heading sub-heading--white landscape-hidden">
#                                 Subscribe to our Newsletter
#                             </p>
# <p class="sub-heading sub-heading--white landscape-only">Newsletter</p>
# <form action="//spiced-academy.us12.list-manage.com/subscribe/post?u=d484949f27c464f21ce2d4182&amp;id=fe8732373f" method="POST" target="_blank">
# <div class="field">
# <input autocomplete="off" class="subscribe-input" id="footer-name" name="NAME" placeholder="Name" required="" type="text"/>
# <label for="footer-name">Name</label>
# </div>
# <div class="field">
# <input autocomplete="off" class="subscribe-input" id="footer-email" name="EMAIL" placeholder="Email" required="" type="email"/>
# <label for="footer-email">Email</label>
# </div>
# <p class="disclaimer">
#                                     * By clicking Submit, I acknowledge that I have read and agree with the Spiced Academy Privacy Policy.
#                                 </p>
# <button class="btn btn--secondary">SUBMIT</button>
# </form>
# <p class="copyright">© 2020 Spiced Academy</p>
# </div>
# </div>
# <div class="panel-footer footer-bottom-right footer-bottom-right--flex">
# <div class="quick-links">
# <p class="footer-title">Quick Links</p>
# <a class="link p-mid-size" href="/program">Programs</a>
# <a class="link p-mid-size" href="/about">About</a>
# </div>
# <div class="social">
# <p class="footer-title">Social</p>
# <div class="footer-icons">
# <a href="https://www.instagram.com/spicedacademy/" rel="nofollow noopener" target="_blank">
# <img alt="instagram" src="/img/icons/instagram-icon.png"/>
# </a>
# <a href="https://www.facebook.com/spicedacademy/" rel="nofollow noopener" target="_blank">
# <img alt="facebook" src="/img/icons/facebook-icon.png"/>
# </a>
# </div>
# </div>
# <div class="contact">
# <p class="footer-title">Contact Info</p>
# <p class="mail-to p-mid-size">
# <a href="mailto:info@spiced-academy.com">info@spiced-academy.com</a>
# </p>
# <p>+49 30 5093 1680</p>
# </div>
# <div class="legal">
# <p class="footer-title">Legal</p>
# <a class="disclaimer" href="/disclaimer">
# <p class="p-mid-size">Disclaimer</p>
# </a>
# <a class="privacy" href="/privacy">
# <p class="p-mid-size">Privacy</p>
# </a>
# <a class="imprint" href="/imprint">
# <p class="p-mid-size">Imprint</p>
# </a>
# </div>
# </div>
# </div>
# </footer>
# </section>
# <div class="js-cookie-warning cookie-warning-container fade-out">
# <div class="cookie-warning-text">
# <p>We use cookies to enhance your experience on our site, and to serve you advertising that may interest you. If that's ok with you, simply close this message and keep browsing. Otherwise, <a href="/privacy">click here to find out more info.</a></p>
# </div>
# <button class="js-close-cookie-warning btn btn--secondary">ACKNOWLEDGE</button>
# </div> </div>
# <script charset="utf-8" src="/js/script.js"></script>
# <script charset="utf-8" src="/js/cookie-warning.js"></script>
# </body>
# </html>

# %%
type(soup)
# this BeautifulSoup object encodes all the hierarchy/ structure of the underlying HTML code
# i. e. it's not longer a simple python string
# Out:
# bs4.BeautifulSoup

# %% [markdown]
# #### So now, with our "beatiful soup-ified" object, we can now much more easily query pieces of the HTML "text" that we care about. We no longer have to write regular expressions from scratch.
#
# - `.find()` always returns the first instance of your "query"
# - `.find_all()` returns a list-like object (called a "ResultSet") that contains at least one matching result
# - `.text` returns the actual part of the tag that is outside of the **<angled brackets>** (i. e. the text)
#
#
# <span style="background-color:lightyellow">Hint: A good way to query/ identify elements of the HTML page is by their **class** or **id**. In HTML, the difference between *class* and *id* is that an *id* is unique, while a *class* is not.
#     </span>

# %%
soup.head.title.text
# we can already descend/ navigate the tree by accessing nested properties through
# "object-oriented" dot notation.
# Out:
# 'Data Science Bootcamp in Germany | Spiced Academy'

# %% [markdown]
# #### We can use `.find()` method to jump straight down to the part of the HTML tree that we care about.

# %% [markdown]
# #### We can search for specific tags:
# - h1, h2, h3, ...., h6
# - p
# - a
# - div
# - body
# - table
#
# #### Tags also have attributes within them, such as:
# - class
# - id

# %%
soup.find('h3', attrs={'class': 'mob-hidden'}).text
# so now we can perform a more specific query
# Out:
# 'Become fluent in using Python to collect, analyze, and visualize data, focusing on the powerful libraries Pandas & NumPy.'

# %%
results = soup.find_all('h3', attrs={'class': 'mob-hidden'})
# please be aware that find_all returns multiple results in some kind of iterable object

# %%
type(results)
# Out:
# bs4.element.ResultSet

# %%
paragraphs = []
for i in results:
    paragraphs.append(i.text)

paragraphs
# Out:
# ['Become fluent in using Python to collect, analyze, and visualize data, focusing on the powerful libraries Pandas & NumPy.',
#  'Delve into the world of supervised and unsupervised learning with the scikit-learn and statsmodels frameworks.',
#  'Organize data in SQL databases like PostgreSQL, fill it with data and run queries.',
#  'Deploy code on remote servers using Docker and AWS, and build an online dashboard.',
#  'Acquire state-of-the-art engineering tools to write, test, and deploy bigger Python applications.',
#  'Use Git and GitHub throughout the course to collaborate & version control your code.']

# %% [markdown]
# #### Let's use our knowledge of BeautifulSoup to parse both the text and the titles.

# %%
result2 = soup.find_all('div', attrs={'class': 'description'})

# %%
result2
# Out:
# [<div class="description">
#  <h3>Data Analysis in Python</h3>
#  <h3 class="mob-hidden">Become fluent in using Python to collect, analyze, and visualize data, focusing on the powerful libraries Pandas &amp; NumPy.</h3>
#  </div>,
#  <div class="description">
#  <h3>Machine Learning</h3>
#  <h3 class="mob-hidden">Delve into the world of supervised and unsupervised learning with the scikit-learn and statsmodels frameworks.</h3>
#  </div>,
#  <div class="description">
#  <h3>PostgreSQL</h3>
#  <h3 class="mob-hidden">Organize data in SQL databases like PostgreSQL, fill it with data and run queries.</h3>
#  </div>,
#  <div class="description">
#  <h3>Data Infrastructure</h3>
#  <h3 class="mob-hidden">Deploy code on remote servers using Docker and AWS, and build an online dashboard.</h3>
#  </div>,
#  <div class="description">
#  <h3>Software Engineering</h3>
#  <h3 class="mob-hidden">Acquire state-of-the-art engineering tools to write, test, and deploy bigger Python applications.</h3>
#  </div>,
#  <div class="description">
#  <h3>Git &amp; Bash</h3>
#  <h3 class="mob-hidden">Use Git and GitHub throughout the course to collaborate &amp; version control your code.</h3>
#  </div>]

# %%
final_results = []
for i in result2:
    title = i.h3.text
    print(title)
    para = i.find('h3', attrs={'class':'mob-hidden'}).text
    result_pair = (title, para)
    final_results.append(result_pair) # append as a tuple
# Out:
# Data Analysis in Python
# Machine Learning
# PostgreSQL
# Data Infrastructure
# Software Engineering
# Git & Bash

# %%
import pandas as pd

# %%
df = pd.DataFrame(final_results)
df
# Out:
#                          0                                                  1
# 0  Data Analysis in Python  Become fluent in using Python to collect, anal...
# 1         Machine Learning  Delve into the world of supervised and unsuper...
# 2               PostgreSQL  Organize data in SQL databases like PostgreSQL...
# 3      Data Infrastructure  Deploy code on remote servers using Docker and...
# 4     Software Engineering  Acquire state-of-the-art engineering tools to ...
# 5               Git & Bash  Use Git and GitHub throughout the course to co...

# %% [markdown]
# #### When you scrape your data, also think about saving the text/ artists to a file.

# %%
df.to_csv('spiced_descriptions.csv')

# %% [markdown]
# ### Scraping in Python:
# 1. Requests + RegEx
# 2. Requests + BeautifulSoup
# 3. Scrapy
